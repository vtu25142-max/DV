# %%
# Let's add a 'Bonus' column with a fixed amount, for example, 5000
df['Bonus'] = 5000

print("DataFrame with 'Bonus' column:")
display(df)
# Out:
# DataFrame with 'Bonus' column:
#   Company     Division      Team Employee_Name  Salary  Bonus
# 0       A        Sales      East         Alice   70000   5000
# 1       A        Sales      West           Bob   75000   5000
# 2       A  Development  Frontend       Charlie   90000   5000
# 3       A  Development   Backend         David   95000   5000
# 4       B        Sales     North           Eve   80000   5000
# 5       B        Sales     South         Frank   82000   5000
# 6       B    Marketing   Digital         Grace   65000   5000
# 7       B    Marketing   Content         Heidi   68000   5000

# %%
df['Total_Compensation'] = df['Salary'] + df['Bonus']

fig = px.sunburst(df,
                  path=['Company', 'Division', 'Team', 'Employee_Name'],
                  values='Total_Compensation',
                  color='Division',
                  title='Company Organizational Structure by Total Compensation')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
