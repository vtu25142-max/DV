# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-9782b736-cd90-453b-ba5e-0dac147262f9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9782b736-cd90-453b-ba5e-0dac147262f9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile

# Unzip the file if it's a zip archive
zip_file_path = 'cleaned_air.csv.zip'
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall('.')

# Now open the extracted CSV file
file = open("cleaned_air.csv", "r")
data = file.read()
print(data.split("\n")[:6])   # Display first few rows
file.close()
# Out:
# ['Operating Airline,Operating Airline IATA Code,Published Airline,Published Airline IATA Code,GEO Summary,GEO Region,Landing Aircraft Type,Aircraft Body Type,Aircraft Manufacturer,Aircraft Model,Landing Count,Total Landed Weight', 'SkyWest Airlines,OO,United Airlines,UA,International,Canada,Passenger,Regional Jet,Bombardier,CRJ2,30,1410000', 'Air Canada,AC,Air Canada,AC,International,Canada,Passenger,Narrow Body,Airbus,A320,125,17787978', 'Japan Airlines,JL,Japan Airlines,JL,International,Asia,Passenger,Wide Body,Boeing,B773,30,16620000', '"COPA Airlines, Inc.",CM,"COPA Airlines, Inc.",CM,International,Central America,Passenger,Narrow Body,Boeing,B739,3,491700', 'Hong Kong Airlines Limited,HX,Hong Kong Airlines Limited,HX,International,Asia,Passenger,Wide Body,Airbus,A359,16,7301712']

# %%
import pandas as pd
df = pd.read_csv('cleaned_air.csv')
df[df["Operating Airline"] == "SkyWest Airlines"]
# Out:
#       Operating Airline Operating Airline IATA Code  \
# 0      SkyWest Airlines                          OO
# 35     SkyWest Airlines                          OO
# 48     SkyWest Airlines                          OO
# 54     SkyWest Airlines                          OO
# 90     SkyWest Airlines                          OO
# ...                 ...                         ...
# 22040  SkyWest Airlines                          OO
# 22041  SkyWest Airlines                          OO
# 22042  SkyWest Airlines                          OO
# 22043  SkyWest Airlines                          OO
# 22044  SkyWest Airlines                          OO
#
#                       Published Airline Published Airline IATA Code  \
# 0                       United Airlines                          UA
# 35                      Alaska Airlines                          AS
# 48                      United Airlines                          UA
# ...

# %%
df[df["Operating Airline"] == "SkyWest Airlines"]
# Out:
#       Operating Airline Operating Airline IATA Code  \
# 0      SkyWest Airlines                          OO
# 35     SkyWest Airlines                          OO
# 48     SkyWest Airlines                          OO
# 54     SkyWest Airlines                          OO
# 90     SkyWest Airlines                          OO
# ...                 ...                         ...
# 22040  SkyWest Airlines                          OO
# 22041  SkyWest Airlines                          OO
# 22042  SkyWest Airlines                          OO
# 22043  SkyWest Airlines                          OO
# 22044  SkyWest Airlines                          OO
#
#                       Published Airline Published Airline IATA Code  \
# 0                       United Airlines                          UA
# 35                      Alaska Airlines                          AS
# 48                      United Airlines                          UA
# ...

# %%
print("Unique GEO Regions:", df["GEO Region"].unique())
print("Number of Aircraft Body Types:", df["Aircraft Body Type"].nunique())
# Out:
# Unique GEO Regions: ['Canada' 'Asia' 'Central America' 'Europe' 'US' 'Mexico'
#  'Australia / Oceania' 'Middle East' 'Caribbean' 'South America']
# Number of Aircraft Body Types: 4

# %%
df["Total Landed Weight"].describe()
# Out:
# count    2.204500e+04
# mean     1.899138e+07
# std      3.033287e+07
# min      6.850000e+03
# 25%      3.035292e+06
# 50%      9.660000e+06
# 75%      1.953000e+07
# max      2.730420e+08
# Name: Total Landed Weight, dtype: float64

# %%
df[df["Total Landed Weight"] > 15000]["Operating Airline"]
# Out:
# 0                  SkyWest Airlines
# 1                        Air Canada
# 2                    Japan Airlines
# 3               COPA Airlines, Inc.
# 4        Hong Kong Airlines Limited
#                     ...
# 22040              SkyWest Airlines
# 22041              SkyWest Airlines
# 22042              SkyWest Airlines
# 22043              SkyWest Airlines
# 22044              SkyWest Airlines
# Name: Operating Airline, Length: 22017, dtype: object

# %%
df[(df["Total Landed Weight"] >= 20000000) & (df["Total Landed Weight"] <= 40000000)]["Operating Airline"]
# Out:
# 15                    Emirates
# 17                  Air France
# 20             Virgin Atlantic
# 28             United Airlines
# 52           American Airlines
#                  ...
# 22011           Japan Airlines
# 22026    Nippon Cargo Airlines
# 22029       Northwest Airlines
# 22030       Northwest Airlines
# 22037       Singapore Airlines
# Name: Operating Airline, Length: 2709, dtype: object
